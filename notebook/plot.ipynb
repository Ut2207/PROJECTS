# %%
import numpy as np
import matplotlib.pyplot as plt

x = np.linspace(0, 10, 100)
y = np.tan(x)

plt.plot(x, y)
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt
fig,ax=subplots()
a=ax.hist(np.random.randn(100),bins=20,color='k',alpha=0.3)
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[8], line 3
#       1 import numpy as np
#       2 import matplotlib.pyplot as plt
# ----> 3 fig,ax=subplots()
#       4 a=ax.hist(np.random.randn(100),bins=20,color='k',alpha=0.3)
#       5 plt.show()
#
# NameError: name 'subplots' is not defined
